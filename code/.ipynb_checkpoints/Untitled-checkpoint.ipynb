# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
df = pd.read_csv('../Data/data_cleaned.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df.head(2)
# Out:
#        country          region  year  happiness_score  \
# 0  Switzerland  Western Europe  2015            7.587
# 1      Iceland  Western Europe  2015            7.561
#
#    economy_(gdp_per_capita)   family  health_(life_expectancy)  freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    trust_(government_corruption)  generosity  dystopia_residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
#
#    food_supply_(kcal/capita/day)  \
# 0                         3460.0
# 1                         3548.0
#
#    crude_birth_rate_(births_per_1,000_population)  \
# 0                                          10.364
# 1                                          12.933
#
#    deaths_-_unsafe_water_source_per_100k_people  \
# 0                                      0.030155
# 1                                      0.021300
#
#    deaths_-_conflict_and_terrorism
# 0                              0.0
# 1                              0.0

# %%
country_to_numeric = {'Sub-Saharan Africa': 0, 'Central and Eastern Europe': 1, 'Latin America and Caribbean': 2, 
                     'Western Europe': 3, 'Middle East and Northern Africa': 4, 'Southeastern Asia': 5,
                     'Southern Asia': 6, 'Eastern Asia': 7, 'North America': 8, 'Australia and New Zealand': 9}

df['region'] = df['region'].replace(country_to_numeric)

# %%
X = df.drop(columns=['year', 'region', 'country'])
y = df['region']

# %%
X
# Out:
#      happiness_score  economy_(gdp_per_capita)    family  \
# 0              7.587                  1.396510  1.349510
# 1              7.561                  1.302320  1.402230
# 2              7.527                  1.325480  1.360580
# 3              7.522                  1.459000  1.330950
# 4              7.427                  1.326290  1.322610
# ..               ...                       ...       ...
# 465            3.471                  0.368746  0.945707
# 466            3.069                  0.747190  0.148660
# 467            3.349                  0.511136  1.041990
# 468            3.462                  0.777153  0.396103
# 469            2.693                  0.000000  0.000000
#
#      health_(life_expectancy)   freedom  trust_(government_corruption)  \
# 0                    0.941430  0.665570                       0.419780
# 1                    0.947840  0.628770                       0.141450
# 2                    0.874640  0.649380                       0.483570
# 3                    0.885210  0.669730                       0.365030
# 4                    0.905630  0.632970                       0.329570
# ..                        ...       ...                            ...
# 465                  0.326425  0.581844                       0.252756
# 466                  0.629940  0.069120                       0.172330
# 467                  0.364509  0.390018                       0.354256
# 468                  0.500533  0.081539                       0.493664
# 469                  0.018773  0.270842                       0.280876
#
#      generosity  dystopia_residual  food_supply_(kcal/capita/day)  \
# 0      0.296780           2.517380                    3460.000000
# 1      0.436300           2.702010                    3548.000000
# 2      0.341390           2.492040                    3315.000000
# 3      0.346990           2.465310                    3435.000000
# 4      0.458110           2.451760                    3438.000000
# ..          ...                ...                            ...
# 465    0.455220           0.540061                    2215.000000
# 466    0.483970           0.817890                    3136.093023
# 467    0.066035           0.621130                    2396.000000
# 468    0.151347           1.061574                    3136.093023
# 469    0.056565           2.066005                    1758.000000
#
#      crude_birth_rate_(births_per_1,000_population)  \
# 0                                            10.364
# 1                                            12.933
# 2                                            10.411
# 3                                            11.397
# 4                                            10.710
# ..                                              ...
# 465                                          32.062
# 466                                          24.525
# 467                                          37.075
# 468                                          24.115
# 469                                          35.660
#
#      deaths_-_unsafe_water_source_per_100k_people  \
# 0                                        0.030155
# 1                                        0.021300
# 2                                        0.071516
# 3                                        0.065375
# 4                                        0.068045
# ..                                            ...
# 465                                     40.604192
# 466                                      0.230011
# 467                                     40.963010
# 468                                      0.226669
# 469                                    150.308479
#
#      deaths_-_conflict_and_terrorism
# 0                           0.000000
# 1                           0.000000
# 2                           0.035288
# 3                           0.000000
# 4                           0.000000
# ..                               ...
# 465                         0.031862
# 466                       308.409636
# 467                         0.079669
# 468                       228.216333
# 469                        40.648997
#
# [470 rows x 12 columns]

# %%
y
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      8
#       ..
# 465    0
# 466    4
# 467    0
# 468    4
# 469    0
# Name: region, Length: 470, dtype: int64

# %%
y = to_categorical(y)

# %%
y.shape
# Out:
# (470, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
ss.fit(X_train, y_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)
X_train.shape
# Out:
# (352, 12)

# %%
def model_func(layer_one_neurons, layer_two_neurons, dropout_percent):
    print('layer_one', layer_one_neurons, 'layer_two', layer_two_neurons) # only to help troubleshoot
    model = Sequential()
    model.add(Dense(layer_one_neurons, activation='relu', input_shape=(5,)))
    model.add(Dropout(dropout_percent))
    model.add(Dense(layer_two_neurons, activation='relu'))
    model.add(Dropout(dropout_percent))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics='accuracy')
    return model

nn = KerasClassifier(build_fn=model_func, batch_size=8, verbose=0)

params = {
    'epochs': [50, 75, 100],
    'layer_one_neurons': [32, 64, 128],
    'layer_two_neurons': [32, 64, 128],
    'dropout_percent': [.25, .5]
}
gs = GridSearchCV(nn, param_grid=params, cv=5)
gs.fit(X_train_sc, y_train)
print(gs.best_score_) # <- negative mean squared error, ie the higher (less negative) the better
gs.best_params_
# Out:
# <ipython-input-21-d03ea12b5f86>:12: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   nn = KerasClassifier(build_fn=model_func, batch_size=8, verbose=0)
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_271" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_272" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 32 layer_two 32
# layer_one 32 layer_two 32
# layer_one 32 layer_two 32
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_273" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_274" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_275" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 32 layer_two 32
# layer_one 32 layer_two 32
# layer_one 32 layer_two 64
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_276" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_277" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_278" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 32 layer_two 64
# layer_one 32 layer_two 64
# layer_one 32 layer_two 64
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_279" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_280" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_281" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 32 layer_two 64
# layer_one 32 layer_two 128
# layer_one 32 layer_two 128
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_282" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_283" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_284" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 32 layer_two 128
# layer_one 32 layer_two 128
# layer_one 32 layer_two 128
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_285" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_286" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_287" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 64 layer_two 32
# layer_one 64 layer_two 32
# layer_one 64 layer_two 32
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_288" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
# ...
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_536" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 128 layer_two 64
# layer_one 128 layer_two 128
# layer_one 128 layer_two 128
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_537" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_538" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_539" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# layer_one 128 layer_two 128
# layer_one 128 layer_two 128
# layer_one 128 layer_two 128
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 232, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1129, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_540" is incompatible with the layer: expected shape=(None, 5), found shape=(None, 12)
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# layer_one 32 layer_two 32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d03ea12b5f86> in <module>
#      19 }
#      20 gs = GridSearchCV(nn, param_grid=params, cv=5)
# ---> 21 gs.fit(X_train_sc, y_train)
#      22 print(gs.best_score_) # <- negative mean squared error, ie the higher (less negative) the better
#      23 gs.best_params_
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     230       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     231     self.n_classes_ = len(self.classes_)
# --> 232     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     233
#     234   def predict(self, x, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     162     fit_args.update(kwargs)
#     163
# --> 164     history = self.model.fit(x, y, **fit_args)
#     165
#     166     return history
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/robertherndon/opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_spec.py", line 263, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_541" is incompatible with the layer: expected shape=(None, 5), found shape=(8, 12)

# %% [markdown]
# # Author: Spencer Buckner & Robb Herndon & Casey Liu

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/world happiness data.csv')
df.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  ...  Deaths - Conflict and terrorism  \
# ...

# %%
df = df.drop(columns = ['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 
                   'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'])

# %%
df.shape
# Out:
# (470, 16)

# %%
df = df.drop(columns = ['Happiness Rank'])

# %%
df['Year'].value_counts()
# Out:
# 2015    158
# 2016    157
# 2017    155
# Name: Year, dtype: int64

# %%
df.columns = [c.replace(' ', '_').lower() for c in df.columns]

# %%
df.head()
# Out:
#        country          region  year  happiness_score  \
# 0  Switzerland  Western Europe  2015            7.587
# 1      Iceland  Western Europe  2015            7.561
# 2      Denmark  Western Europe  2015            7.527
# 3       Norway  Western Europe  2015            7.522
# 4       Canada   North America  2015            7.427
#
#    economy_(gdp_per_capita)   family  health_(life_expectancy)  freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    trust_(government_corruption)  generosity  dystopia_residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# ...

# %%
df.isnull().sum()
# Out:
# country                                            0
# region                                             0
# year                                               0
# happiness_score                                    0
# economy_(gdp_per_capita)                           0
# family                                             0
# health_(life_expectancy)                           0
# freedom                                            0
# trust_(government_corruption)                      0
# generosity                                         0
# dystopia_residual                                  0
# food_supply_(kcal/capita/day)                     49
# crude_birth_rate_(births_per_1,000_population)    18
# deaths_-_unsafe_water_source_per_100k_people      21
# deaths_-_conflict_and_terrorism                   21
# dtype: int64

# %%
#['food_supply_(kcal/capita/day)']
df.groupby('region').mean()['food_supply_(kcal/capita/day)'].loc['Eastern Asia']
# Out:
# 2984.777777777778

# %% [markdown]
# # Thought process for this section:
#  - Check for which regions have nulls in the 'food_supply_(kcal/capita/day)' column
#  - Create list of those regions
#  - Create for loop to fill each regions nulls with the mean of the values for that region

# %% [markdown]
# ## Food Supply

# %%
df[df['food_supply_(kcal/capita/day)'].isnull()]
# Out:
#                      country                           region  year  \
# 23                   Bahrain  Middle East and Northern Africa  2015
# 27                   Bahrain  Middle East and Northern Africa  2016
# 30                   Bahrain  Middle East and Northern Africa  2017
# 48                    Bhutan                    Southern Asia  2015
# 62                    Bhutan                    Southern Asia  2016
# 65                    Bhutan                    Southern Asia  2017
# 68                   Burundi               Sub-Saharan Africa  2015
# 78                   Burundi               Sub-Saharan Africa  2016
# 90                   Burundi               Sub-Saharan Africa  2017
# 92                   Comoros               Sub-Saharan Africa  2015
# 100                  Comoros               Sub-Saharan Africa  2016
# 107      Congo (Brazzaville)               Sub-Saharan Africa  2015
# 119      Congo (Brazzaville)               Sub-Saharan Africa  2016
# ...

# %% [markdown]
#  ### Regions with nulls in food supply column
#  1. Middle East and Northern Africa
#  2. Southern Asia
#  3. Sub-Saharan Africa
#  4. Central and Eastern Europe
#  5. Western Europe
#  6. Latin America and Caribbean
#  7. Southeastern Asia

# %%
regions = ['Middle East and Northern Africa', 'Southern Asia', 'Sub-Saharan Africa', 
            'Central and Eastern Europe', 'Western Europe', 'Latin America and Caribbean',
           'Southeastern Asia', 'Australia and New Zealand', 'Eastern Asia', 'North America']

# %%
# df.loc[(df['region'] == 'Middle East and Northern Africa') & (df['food_supply_(kcal/capita/day)'].isnull()), 'food_supply_(kcal/capita/day)'] = df.loc[(df['region'] == 'Middle East and Northern Africa'), 'food_supply_(kcal/capita/day)'].mean()

# This was test code we used in the for loop below

# %%
for i in regions:
    df.loc[(df['region'] == i) & (df['food_supply_(kcal/capita/day)'].isnull()), 'food_supply_(kcal/capita/day)'] = df.loc[(df['region'] == i), 'food_supply_(kcal/capita/day)'].mean()

# %%
df.isnull().sum()
# Out:
# country                                            0
# region                                             0
# year                                               0
# happiness_score                                    0
# economy_(gdp_per_capita)                           0
# family                                             0
# health_(life_expectancy)                           0
# freedom                                            0
# trust_(government_corruption)                      0
# generosity                                         0
# dystopia_residual                                  0
# food_supply_(kcal/capita/day)                      0
# crude_birth_rate_(births_per_1,000_population)    18
# deaths_-_unsafe_water_source_per_100k_people      21
# deaths_-_conflict_and_terrorism                   21
# dtype: int64

# %% [markdown]
# ## Crude Birth Rate

# %%
df[df['crude_birth_rate_(births_per_1,000_population)'].isnull()]
# Out:
#                  country                      region  year  happiness_score  \
# 107  Congo (Brazzaville)          Sub-Saharan Africa  2015            3.989
# 119  Congo (Brazzaville)          Sub-Saharan Africa  2016            4.236
# 138  Congo (Brazzaville)          Sub-Saharan Africa  2017            4.291
# 139     Congo (Kinshasa)          Sub-Saharan Africa  2015            4.517
# 150     Congo (Kinshasa)          Sub-Saharan Africa  2016            4.272
# 155     Congo (Kinshasa)          Sub-Saharan Africa  2017            4.280
# 219               Kosovo  Central and Eastern Europe  2015            5.589
# 224               Kosovo  Central and Eastern Europe  2016            5.401
# 233               Kosovo  Central and Eastern Europe  2017            5.279
# 254            Macedonia  Central and Eastern Europe  2015            5.007
# 265            Macedonia  Central and Eastern Europe  2016            5.121
# ...

# %% [markdown]
# ### Regions with nulls for crude birthrate
# 1. Sub-Saharan Africa
# 2. Central and Eastern Europe
# 3. Western Europe

# %%
for i in regions:
    df.loc[(df['region'] == i) & (df['crude_birth_rate_(births_per_1,000_population)'].isnull()), 'crude_birth_rate_(births_per_1,000_population)'] = df.loc[(df['region'] == i), 'crude_birth_rate_(births_per_1,000_population)'].mean()

# %%
df.isnull().sum()
# Out:
# country                                            0
# region                                             0
# year                                               0
# happiness_score                                    0
# economy_(gdp_per_capita)                           0
# family                                             0
# health_(life_expectancy)                           0
# freedom                                            0
# trust_(government_corruption)                      0
# generosity                                         0
# dystopia_residual                                  0
# food_supply_(kcal/capita/day)                      0
# crude_birth_rate_(births_per_1,000_population)     0
# deaths_-_unsafe_water_source_per_100k_people      21
# deaths_-_conflict_and_terrorism                   21
# dtype: int64

# %% [markdown]
# ## Deaths - Unsafe Water Source

# %%
df[df['deaths_-_unsafe_water_source_per_100k_people'].isnull()]
# Out:
#                  country                      region  year  happiness_score  \
# 71             Hong Kong                Eastern Asia  2015            5.474
# 107  Congo (Brazzaville)          Sub-Saharan Africa  2015            3.989
# 119  Congo (Brazzaville)          Sub-Saharan Africa  2016            4.236
# 138  Congo (Brazzaville)          Sub-Saharan Africa  2017            4.291
# 139     Congo (Kinshasa)          Sub-Saharan Africa  2015            4.517
# 150     Congo (Kinshasa)          Sub-Saharan Africa  2016            4.272
# 155     Congo (Kinshasa)          Sub-Saharan Africa  2017            4.280
# 219               Kosovo  Central and Eastern Europe  2015            5.589
# 224               Kosovo  Central and Eastern Europe  2016            5.401
# 232            Hong Kong                Eastern Asia  2016            5.458
# 233               Kosovo  Central and Eastern Europe  2017            5.279
# ...

# %% [markdown]
# ### Regions with nulls for unsafe water source
# 1. Sub-Saharan Africa
# 2. Eastern Asia
# 3. Central and Eastern Europe
# 4. Western Europe

# %%
for i in regions:
    df.loc[(df['region'] == i) & (df['deaths_-_unsafe_water_source_per_100k_people'].isnull()), 'deaths_-_unsafe_water_source_per_100k_people'] = df.loc[(df['region'] == i), 'deaths_-_unsafe_water_source_per_100k_people'].mean()

# %%
df.isnull().sum()
# Out:
# country                                            0
# region                                             0
# year                                               0
# happiness_score                                    0
# economy_(gdp_per_capita)                           0
# family                                             0
# health_(life_expectancy)                           0
# freedom                                            0
# trust_(government_corruption)                      0
# generosity                                         0
# dystopia_residual                                  0
# food_supply_(kcal/capita/day)                      0
# crude_birth_rate_(births_per_1,000_population)     0
# deaths_-_unsafe_water_source_per_100k_people       0
# deaths_-_conflict_and_terrorism                   21
# dtype: int64

# %% [markdown]
# ## Deaths - Conflict and Terrorism

# %%
df[df['deaths_-_conflict_and_terrorism'].isnull()]
# Out:
#                  country                      region  year  happiness_score  \
# 71             Hong Kong                Eastern Asia  2015            5.474
# 107  Congo (Brazzaville)          Sub-Saharan Africa  2015            3.989
# 119  Congo (Brazzaville)          Sub-Saharan Africa  2016            4.236
# 138  Congo (Brazzaville)          Sub-Saharan Africa  2017            4.291
# 139     Congo (Kinshasa)          Sub-Saharan Africa  2015            4.517
# 150     Congo (Kinshasa)          Sub-Saharan Africa  2016            4.272
# 155     Congo (Kinshasa)          Sub-Saharan Africa  2017            4.280
# 219               Kosovo  Central and Eastern Europe  2015            5.589
# 224               Kosovo  Central and Eastern Europe  2016            5.401
# 232            Hong Kong                Eastern Asia  2016            5.458
# 233               Kosovo  Central and Eastern Europe  2017            5.279
# ...

# %% [markdown]
# ### Regions with nulls for conflict and terrorism
# 1. Sub-Saharan Africa
# 2. Eastern Asia
# 3. Central and Eastern Europe
# 4. Western Europe

# %%
for i in regions:
    df.loc[(df['region'] == i) & (df['deaths_-_conflict_and_terrorism'].isnull()), 'deaths_-_conflict_and_terrorism'] = df.loc[(df['region'] == i), 'deaths_-_conflict_and_terrorism'].mean()

# %%
df.isnull().sum()
# Out:
# country                                           0
# region                                            0
# year                                              0
# happiness_score                                   0
# economy_(gdp_per_capita)                          0
# family                                            0
# health_(life_expectancy)                          0
# freedom                                           0
# trust_(government_corruption)                     0
# generosity                                        0
# dystopia_residual                                 0
# food_supply_(kcal/capita/day)                     0
# crude_birth_rate_(births_per_1,000_population)    0
# deaths_-_unsafe_water_source_per_100k_people      0
# deaths_-_conflict_and_terrorism                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 15 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   country                                         470 non-null    object
#  1   region                                          470 non-null    object
#  2   year                                            470 non-null    int64
#  3   happiness_score                                 470 non-null    float64
#  4   economy_(gdp_per_capita)                        470 non-null    float64
#  5   family                                          470 non-null    float64
#  6   health_(life_expectancy)                        470 non-null    float64
#  7   freedom                                         470 non-null    float64
#  8   trust_(government_corruption)                   470 non-null    float64
# ...

# %%
df.describe()
# Out:
#               year  happiness_score  economy_(gdp_per_capita)      family  \
# count   470.000000       470.000000                470.000000  470.000000
# mean   2015.993617         5.370728                  0.927830    0.990347
# std       0.816907         1.136998                  0.415584    0.318707
# min    2015.000000         2.693000                  0.000000    0.000000
# 25%    2015.000000         4.509000                  0.605292    0.793000
# 50%    2016.000000         5.282500                  0.995439    1.025665
# 75%    2017.000000         6.233750                  1.252443    1.228745
# max    2017.000000         7.587000                  1.870766    1.610574
#
#        health_(life_expectancy)     freedom  trust_(government_corruption)  \
# count                470.000000  470.000000                     470.000000
# mean                   0.579968    0.402828                       0.175605
# std                    0.240161    0.150356                       0.131909
# ...

# %% [markdown]
# ### There are several countries with 0 for the score, however, the score is only the extent to which that feature contributes to the calculation of the Happiness Score.

# %%
df.to_csv('Data/data_cleaned.csv')

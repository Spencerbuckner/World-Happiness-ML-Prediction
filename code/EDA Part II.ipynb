# %% [markdown]
# # Author: Robb Herndon

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/data_cleaned.csv')

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df.head()
# Out:
#        country          region  year  happiness_score  \
# 0  Switzerland  Western Europe  2015            7.587
# 1      Iceland  Western Europe  2015            7.561
# 2      Denmark  Western Europe  2015            7.527
# 3       Norway  Western Europe  2015            7.522
# 4       Canada   North America  2015            7.427
#
#    economy_(gdp_per_capita)   family  health_(life_expectancy)  freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    trust_(government_corruption)  generosity  dystopia_residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# ...

# %%
df['region'].value_counts()
# Out:
# Sub-Saharan Africa                 117
# Central and Eastern Europe          87
# Latin America and Caribbean         68
# Western Europe                      63
# Middle East and Northern Africa     58
# Southeastern Asia                   26
# Southern Asia                       21
# Eastern Asia                        18
# Australia and New Zealand            6
# North America                        6
# Name: region, dtype: int64

# %% [markdown]
# ## Western Europe

# %%
w_europe = df[df['region'] == 'Western Europe']
w_europe.shape
# Out:
# (63, 15)

# %%
w_europe['economy_(gdp_per_capita)'].mean()
# Out:
# 1.391020764

# %%
w_europe['family'].mean()
# Out:
# 1.244899981539683

# %%
w_europe['health_(life_expectancy)'].mean()
# Out:
# 0.8531917919206347

# %%
w_europe['freedom'].mean()
# Out:
# 0.5142128786666667

# %%
w_europe['trust_(government_corruption)'].mean()
# Out:
# 0.255834622111111

# %%
w_europe['generosity'].mean()
# Out:
# 0.2752742406825396

# %%
w_europe_corr = w_europe.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(w_europe_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(w_europe_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## North America

# %%
n_america = df[df['region'] == 'North America']
n_america.shape
# Out:
# (6, 15)

# %%
n_america_corr = n_america.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(n_america_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(n_america_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask)
plt.xticks(rotation=40)
plt.savefig('../visuals/heatmap_NA', bbox_inches='tight');

# %% [markdown]
# ## Sub-Saharan Africa

# %%
sub_sah_africa = df[df['region'] == 'Sub-Saharan Africa']
sub_sah_africa.shape
# Out:
# (117, 15)

# %%
sub_s_africa_corr = sub_sah_africa.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(sub_s_africa_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(sub_s_africa_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask)
plt.xticks(rotation=40)
plt.savefig('../visuals/heatmap_SSA', bbox_inches='tight');

# %% [markdown]
# ## Central and Eastern Europe

# %%
cen_and_east_europe = df[df['region'] == 'Central and Eastern Europe']
cen_and_east_europe.shape
# Out:
# (87, 15)

# %%
cen_east_europe_corr = cen_and_east_europe.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(cen_east_europe_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(cen_east_europe_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## Latin America and Caribbean

# %%
lat_america_car = df[df['region'] == 'Latin America and Caribbean']
lat_america_car.shape
# Out:
# (68, 15)

# %%
lat_america_corr = lat_america_car.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(lat_america_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(lat_america_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## Middle East and Northern Africa

# %%
mid_east_n_africa = df[df['region'] == 'Middle East and Northern Africa']
mid_east_n_africa.shape
# Out:
# (58, 15)

# %%
mideast_nafrica_corr = mid_east_n_africa.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(mideast_nafrica_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(mideast_nafrica_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## Southeastern Asia

# %%
se_asia = df[df['region'] == 'Southeastern Asia']
se_asia.shape
# Out:
# (26, 15)

# %%
se_asia_corr = se_asia.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(se_asia_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(se_asia_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask)
plt.xticks(rotation=40)
plt.savefig('../visuals/heatmap_SeA');

# %% [markdown]
# ## Southern Asia

# %%
south_asia = df[df['region'] == 'Southern Asia']
south_asia.shape
# Out:
# (21, 15)

# %%
s_asia_corr = south_asia.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(s_asia_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(s_asia_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## Eastern Asia

# %%
east_asia = df[df['region'] == 'Eastern Asia']
east_asia.shape
# Out:
# (18, 15)

# %%
e_asia_corr = east_asia.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(e_asia_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(e_asia_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %% [markdown]
# ## Australia and New Zealand

# %%
aus_and_nz = df[df['region'] == 'Australia and New Zealand']
aus_and_nz.shape
# Out:
# (6, 15)

# %%
aus_nz_corr = aus_and_nz.corr()
plt.figure(figsize=(20, 20))
mask = np.zeros_like(aus_nz_corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(aus_nz_corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, mask=mask);

# %%
# plt.figure(figsize=(20,10))
sns.pairplot(df);

# %%
df.hist(bins=30, figsize=(20,10));

# %%
df.dtypes
# Out:
# country                                            object
# region                                             object
# year                                                int64
# happiness_score                                   float64
# economy_(gdp_per_capita)                          float64
# family                                            float64
# health_(life_expectancy)                          float64
# freedom                                           float64
# trust_(government_corruption)                     float64
# generosity                                        float64
# dystopia_residual                                 float64
# food_supply_(kcal/capita/day)                     float64
# crude_birth_rate_(births_per_1,000_population)    float64
# deaths_-_unsafe_water_source_per_100k_people      float64
# deaths_-_conflict_and_terrorism                   float64
# dtype: object

# %%
data = df.drop(columns=['country', 'region', 'year'])

# %%
data.hist(bins=30, figsize=(20,10));

# %%
# Got the idea to do VIF from a friend, here is the data for VIF:
# https://stackoverflow.com/questions/42658379/variance-inflation-factor-in-python, 
# https://www.statisticshowto.com/variance-inflation-factor/
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = data.columns

# %%
data
# Out:
#      happiness_score  economy_(gdp_per_capita)    family  \
# 0              7.587                  1.396510  1.349510
# 1              7.561                  1.302320  1.402230
# 2              7.527                  1.325480  1.360580
# 3              7.522                  1.459000  1.330950
# 4              7.427                  1.326290  1.322610
# ..               ...                       ...       ...
# 465            3.471                  0.368746  0.945707
# 466            3.069                  0.747190  0.148660
# 467            3.349                  0.511136  1.041990
# 468            3.462                  0.777153  0.396103
# 469            2.693                  0.000000  0.000000
#
#      health_(life_expectancy)   freedom  trust_(government_corruption)  \
# 0                    0.941430  0.665570                       0.419780
# 1                    0.947840  0.628770                       0.141450
# ...

# %%
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(data.values, i)
                          for i in range(len(data.columns))]
print(vif_data)
# Food_supply and generosity seem to have the highest multicollinearity
# Out:
#                                            feature           VIF
# 0                                  happiness_score  3.666860e+08
# 1                         economy_(gdp_per_capita)  1.257324e+07
# 2                                           family  1.316832e+07
# 3                         health_(life_expectancy)  4.792196e+06
# 4                                          freedom  2.248607e+06
# 5                    trust_(government_corruption)  5.865673e+05
# 6                                       generosity  7.092223e+05
# 7                                dystopia_residual  5.717523e+07
# 8                    food_supply_(kcal/capita/day)  7.161939e+01
# 9   crude_birth_rate_(births_per_1,000_population)  1.673933e+01
# 10    deaths_-_unsafe_water_source_per_100k_people  4.613013e+00
# 11                 deaths_-_conflict_and_terrorism  1.285086e+00

# %%
# Also got idea to do PCA testing from friend
# Here is documentation on PCA: 
#https://www.geeksforgeeks.org/ml-principal-component-analysispca/#:~:text=Principal%20Component%20Analysis%20(PCA)%20is,machine%20learning%20for%20predictive%20models.

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
data_sc = ss.fit_transform(data)
data_sc = pd.DataFrame(data_sc, columns=data.columns)
data_sc.head()
# Out:
#    happiness_score  economy_(gdp_per_capita)    family  \
# 0         1.951308                  1.128964  1.128139
# 1         1.928417                  0.902078  1.293734
# 2         1.898482                  0.957866  1.162910
# 3         1.894079                  1.279491  1.069842
# 4         1.810437                  0.959817  1.043646
#
#    health_(life_expectancy)   freedom  trust_(government_corruption)  \
# 0                  1.506687  1.749332                       1.853052
# 1                  1.533406  1.504319                      -0.259207
# 2                  1.228285  1.641540                       2.337158
# 3                  1.272344  1.777030                       1.437552
# 4                  1.357461  1.532282                       1.168445
#
#    generosity  dystopia_residual  food_supply_(kcal/capita/day)  \
# 0    0.716576           0.751391                       1.274640
# 1    1.765050           1.078072                       1.472728
# ...

# %%
# https://www.kaggle.com/redrobb07/30days-hypertuning-lgbm
from sklearn.decomposition import PCA
pcamodel = PCA(n_components=4)
pca = pcamodel.fit_transform(data_sc)
pca.shape
# Out:
# (470, 4)

# %%
plt.scatter(pca[:, 0], pca[:, 1]);

# %%
plt.figure(figsize=(10,10))
plt.bar(range(1,len(pcamodel.explained_variance_ratio_ )+1),pcamodel.explained_variance_ratio_ )
plt.title('Explain Variance by Principal Components', fontsize=12)
plt.ylabel('Explained variance Ratio', fontsize=12)
plt.xlabel('Principal Components', fontsize=12)
plt.plot(range(1,len(pcamodel.explained_variance_ratio_ )+1),
         np.cumsum(pcamodel.explained_variance_ratio_),
         c='red',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')
plt.savefig('../visuals/cummulative_explained_difference.png');

# %%
plt.figure(figsize=(16,8))
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'black', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

myplot(pca[:,0:2],np.transpose(pcamodel.components_[0:2, :]),list(data.columns))
plt.title('Principle Component Map', fontsize=12)
plt.savefig('../visuals/primary_component_map.png', bbox_inches='tight')
plt.show();

# %%
#https://stackoverflow.com/questions/17778394/list-highest-correlation-pairs-from-a-large-correlation-matrix-in-pandas
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(data, 50))
# Out:
# Top Absolute Correlations
# health_(life_expectancy)                        crude_birth_rate_(births_per_1,000_population)    0.873203
# economy_(gdp_per_capita)                        crude_birth_rate_(births_per_1,000_population)    0.816327
# crude_birth_rate_(births_per_1,000_population)  deaths_-_unsafe_water_source_per_100k_people      0.801762
# health_(life_expectancy)                        deaths_-_unsafe_water_source_per_100k_people      0.799912
# economy_(gdp_per_capita)                        health_(life_expectancy)                          0.792224
# happiness_score                                 economy_(gdp_per_capita)                          0.785450
#                                                 health_(life_expectancy)                          0.748040
# economy_(gdp_per_capita)                        food_supply_(kcal/capita/day)                     0.738335
# ...

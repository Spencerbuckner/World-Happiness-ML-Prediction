# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
df = pd.read_csv('./Data/data_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0      country          region  year  happiness_score  \
# 0           0  Switzerland  Western Europe  2015            7.587
# 1           1      Iceland  Western Europe  2015            7.561
# 2           2      Denmark  Western Europe  2015            7.527
# 3           3       Norway  Western Europe  2015            7.522
# 4           4       Canada   North America  2015            7.427
#
#    economy_(gdp_per_capita)   family  health_(life_expectancy)  freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    trust_(government_corruption)  generosity  dystopia_residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176
#
#    food_supply_(kcal/capita/day)  \
# 0                         3460.0
# 1                         3548.0
# 2                         3315.0
# 3                         3435.0
# 4                         3438.0
#
#    crude_birth_rate_(births_per_1,000_population)  \
# 0                                          10.364
# 1                                          12.933
# 2                                          10.411
# 3                                          11.397
# 4                                          10.710
#
#    deaths_-_unsafe_water_source_per_100k_people  \
# 0                                      0.030155
# 1                                      0.021300
# 2                                      0.071516
# 3                                      0.065375
# 4                                      0.068045
#
#    deaths_-_conflict_and_terrorism
# 0                         0.000000
# 1                         0.000000
# 2                         0.035288
# 3                         0.000000
# 4                         0.000000

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df['region'].value_counts()
# Out:
# Sub-Saharan Africa                 117
# Central and Eastern Europe          87
# Latin America and Caribbean         68
# Western Europe                      63
# Middle East and Northern Africa     58
# Southeastern Asia                   26
# Southern Asia                       21
# Eastern Asia                        18
# North America                        6
# Australia and New Zealand            6
# Name: region, dtype: int64

# %%
country_to_numeric = {'Sub-Saharan Africa': 1, 'Central and Eastern Europe': 2, 'Latin America and Caribbean': 3, 
                     'Western Europe': 4, 'Middle East and Northern Africa': 5, 'Southeastern Asia': 6,
                     'Southern Asia': 7, 'Eastern Asia': 8, 'North America': 9, 'Australia and New Zealand': 10}

df['region'] = df['region'].replace(country_to_numeric)

# %%
df.dtypes
# Out:
# country                                            object
# region                                              int64
# year                                                int64
# happiness_score                                   float64
# economy_(gdp_per_capita)                          float64
# family                                            float64
# health_(life_expectancy)                          float64
# freedom                                           float64
# trust_(government_corruption)                     float64
# generosity                                        float64
# dystopia_residual                                 float64
# food_supply_(kcal/capita/day)                     float64
# crude_birth_rate_(births_per_1,000_population)    float64
# deaths_-_unsafe_water_source_per_100k_people      float64
# deaths_-_conflict_and_terrorism                   float64
# dtype: object

# %%
X = df.drop(columns=['country', 'region'])
y = df['region']

# %%
# Instantiate PolynomialFeatures
poly = PolynomialFeatures(include_bias=False)
poly.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
# Create X_poly
X_poly = poly.transform(X)
X_poly
# Out:
# array([[2.01500000e+03, 7.58700000e+00, 1.39651000e+00, ...,
#         9.09347787e-04, 0.00000000e+00, 0.00000000e+00],
#        [2.01500000e+03, 7.56100000e+00, 1.30232000e+00, ...,
#         4.53702482e-04, 0.00000000e+00, 0.00000000e+00],
#        [2.01500000e+03, 7.52700000e+00, 1.32548000e+00, ...,
#         5.11451980e-03, 2.52364419e-03, 1.24523518e-03],
#        ...,
#        [2.01700000e+03, 3.34899998e+00, 5.11135876e-01, ...,
#         1.67796819e+03, 3.26349282e+00, 6.34719147e-03],
#        [2.01700000e+03, 3.46199989e+00, 7.77153134e-01, ...,
#         5.13788301e-02, 5.17295652e+01, 5.20826946e+04],
#        [2.01700000e+03, 2.69300008e+00, 0.00000000e+00, ...,
#         2.25926389e+04, 6.10988891e+03, 1.65234095e+03]])

# %%
poly.get_feature_names(X.columns)
# Out:
# ['year',
#  'happiness_score',
#  'economy_(gdp_per_capita)',
#  'family',
#  'health_(life_expectancy)',
#  'freedom',
#  'trust_(government_corruption)',
#  'generosity',
#  'dystopia_residual',
#  'food_supply_(kcal/capita/day)',
#  'crude_birth_rate_(births_per_1,000_population)',
#  'deaths_-_unsafe_water_source_per_100k_people',
#  'deaths_-_conflict_and_terrorism',
#  'year^2',
#  'year happiness_score',
#  'year economy_(gdp_per_capita)',
#  'year family',
#  'year health_(life_expectancy)',
#  'year freedom',
#  'year trust_(government_corruption)',
#  'year generosity',
#  'year dystopia_residual',
#  'year food_supply_(kcal/capita/day)',
#  'year crude_birth_rate_(births_per_1,000_population)',
#  'year deaths_-_unsafe_water_source_per_100k_people',
#  'year deaths_-_conflict_and_terrorism',
#  'happiness_score^2',
#  'happiness_score economy_(gdp_per_capita)',
#  'happiness_score family',
#  'happiness_score health_(life_expectancy)',
#  'happiness_score freedom',
#  'happiness_score trust_(government_corruption)',
#  'happiness_score generosity',
#  'happiness_score dystopia_residual',
#  'happiness_score food_supply_(kcal/capita/day)',
#  'happiness_score crude_birth_rate_(births_per_1,000_population)',
#  'happiness_score deaths_-_unsafe_water_source_per_100k_people',
#  'happiness_score deaths_-_conflict_and_terrorism',
#  'economy_(gdp_per_capita)^2',
#  'economy_(gdp_per_capita) family',
#  'economy_(gdp_per_capita) health_(life_expectancy)',
#  'economy_(gdp_per_capita) freedom',
#  'economy_(gdp_per_capita) trust_(government_corruption)',
#  'economy_(gdp_per_capita) generosity',
#  'economy_(gdp_per_capita) dystopia_residual',
#  'economy_(gdp_per_capita) food_supply_(kcal/capita/day)',
#  'economy_(gdp_per_capita) crude_birth_rate_(births_per_1,000_population)',
#  'economy_(gdp_per_capita) deaths_-_unsafe_water_source_per_100k_people',
#  'economy_(gdp_per_capita) deaths_-_conflict_and_terrorism',
#  'family^2',
#  'family health_(life_expectancy)',
#  'family freedom',
#  'family trust_(government_corruption)',
#  'family generosity',
#  'family dystopia_residual',
#  'family food_supply_(kcal/capita/day)',
#  'family crude_birth_rate_(births_per_1,000_population)',
#  'family deaths_-_unsafe_water_source_per_100k_people',
#  'family deaths_-_conflict_and_terrorism',
#  'health_(life_expectancy)^2',
#  'health_(life_expectancy) freedom',
#  'health_(life_expectancy) trust_(government_corruption)',
#  'health_(life_expectancy) generosity',
#  'health_(life_expectancy) dystopia_residual',
#  'health_(life_expectancy) food_supply_(kcal/capita/day)',
#  'health_(life_expectancy) crude_birth_rate_(births_per_1,000_population)',
#  'health_(life_expectancy) deaths_-_unsafe_water_source_per_100k_people',
#  'health_(life_expectancy) deaths_-_conflict_and_terrorism',
#  'freedom^2',
#  'freedom trust_(government_corruption)',
#  'freedom generosity',
#  'freedom dystopia_residual',
#  'freedom food_supply_(kcal/capita/day)',
#  'freedom crude_birth_rate_(births_per_1,000_population)',
#  'freedom deaths_-_unsafe_water_source_per_100k_people',
#  'freedom deaths_-_conflict_and_terrorism',
#  'trust_(government_corruption)^2',
#  'trust_(government_corruption) generosity',
#  'trust_(government_corruption) dystopia_residual',
#  'trust_(government_corruption) food_supply_(kcal/capita/day)',
#  'trust_(government_corruption) crude_birth_rate_(births_per_1,000_population)',
#  'trust_(government_corruption) deaths_-_unsafe_water_source_per_100k_people',
#  'trust_(government_corruption) deaths_-_conflict_and_terrorism',
#  'generosity^2',
#  'generosity dystopia_residual',
#  'generosity food_supply_(kcal/capita/day)',
#  'generosity crude_birth_rate_(births_per_1,000_population)',
#  'generosity deaths_-_unsafe_water_source_per_100k_people',
#  'generosity deaths_-_conflict_and_terrorism',
#  'dystopia_residual^2',
#  'dystopia_residual food_supply_(kcal/capita/day)',
#  'dystopia_residual crude_birth_rate_(births_per_1,000_population)',
#  'dystopia_residual deaths_-_unsafe_water_source_per_100k_people',
#  'dystopia_residual deaths_-_conflict_and_terrorism',
#  'food_supply_(kcal/capita/day)^2',
#  'food_supply_(kcal/capita/day) crude_birth_rate_(births_per_1,000_population)',
#  'food_supply_(kcal/capita/day) deaths_-_unsafe_water_source_per_100k_people',
#  'food_supply_(kcal/capita/day) deaths_-_conflict_and_terrorism',
#  'crude_birth_rate_(births_per_1,000_population)^2',
#  'crude_birth_rate_(births_per_1,000_population) deaths_-_unsafe_water_source_per_100k_people',
#  'crude_birth_rate_(births_per_1,000_population) deaths_-_conflict_and_terrorism',
#  'deaths_-_unsafe_water_source_per_100k_people^2',
#  'deaths_-_unsafe_water_source_per_100k_people deaths_-_conflict_and_terrorism',
#  'deaths_-_conflict_and_terrorism^2']

# %%
# View X_poly in a DataFrame
pd.DataFrame(X_poly, columns=poly.get_feature_names(X.columns))
# Out:
#        year  happiness_score  economy_(gdp_per_capita)    family  \
# 0    2015.0            7.587                  1.396510  1.349510
# 1    2015.0            7.561                  1.302320  1.402230
# 2    2015.0            7.527                  1.325480  1.360580
# 3    2015.0            7.522                  1.459000  1.330950
# 4    2015.0            7.427                  1.326290  1.322610
# ..      ...              ...                       ...       ...
# 465  2017.0            3.471                  0.368746  0.945707
# 466  2016.0            3.069                  0.747190  0.148660
# 467  2017.0            3.349                  0.511136  1.041990
# 468  2017.0            3.462                  0.777153  0.396103
# 469  2017.0            2.693                  0.000000  0.000000
#
#      health_(life_expectancy)   freedom  trust_(government_corruption)  \
# 0                    0.941430  0.665570                       0.419780
# 1                    0.947840  0.628770                       0.141450
# 2                    0.874640  0.649380                       0.483570
# 3                    0.885210  0.669730                       0.365030
# 4                    0.905630  0.632970                       0.329570
# ..                        ...       ...                            ...
# 465                  0.326425  0.581844                       0.252756
# 466                  0.629940  0.069120                       0.172330
# 467                  0.364509  0.390018                       0.354256
# 468                  0.500533  0.081539                       0.493664
# 469                  0.018773  0.270842                       0.280876
#
#      generosity  dystopia_residual  food_supply_(kcal/capita/day)  ...  \
# 0      0.296780           2.517380                    3460.000000  ...
# 1      0.436300           2.702010                    3548.000000  ...
# 2      0.341390           2.492040                    3315.000000  ...
# 3      0.346990           2.465310                    3435.000000  ...
# 4      0.458110           2.451760                    3438.000000  ...
# ..          ...                ...                            ...  ...
# 465    0.455220           0.540061                    2215.000000  ...
# 466    0.483970           0.817890                    3136.093023  ...
# 467    0.066035           0.621130                    2396.000000  ...
# 468    0.151347           1.061574                    3136.093023  ...
# 469    0.056565           2.066005                    1758.000000  ...
#
#      food_supply_(kcal/capita/day)^2  \
# 0                       1.197160e+07
# 1                       1.258830e+07
# 2                       1.098922e+07
# 3                       1.179922e+07
# 4                       1.181984e+07
# ..                               ...
# 465                     4.906225e+06
# 466                     9.835079e+06
# 467                     5.740816e+06
# 468                     9.835079e+06
# 469                     3.090564e+06
#
#      food_supply_(kcal/capita/day) crude_birth_rate_(births_per_1,000_population)  \
# 0                                         35859.440000
# 1                                         45886.284000
# 2                                         34512.465000
# 3                                         39148.695000
# 4                                         36820.980000
# ..                                                 ...
# 465                                       71017.330000
# 466                                       76912.681395
# 467                                       88831.700000
# 468                                       75626.883256
# 469                                       62690.280000
#
#      food_supply_(kcal/capita/day) deaths_-_unsafe_water_source_per_100k_people  \
# 0                                           104.337663
# 1                                            75.573440
# 2                                           237.075112
# 3                                           224.562651
# 4                                           233.939662
# ..                                                 ...
# 465                                       89938.284527
# 466                                         721.336946
# 467                                       98147.372104
# 468                                         710.855032
# 469                                      264242.306434
#
#      food_supply_(kcal/capita/day) deaths_-_conflict_and_terrorism  \
# 0                                             0.000000
# 1                                             0.000000
# 2                                           116.979355
# 3                                             0.000000
# 4                                             0.000000
# ..                                                 ...
# 465                                          70.574146
# 466                                      967201.307764
# 467                                         190.887554
# 468                                      715707.649401
# 469                                       71460.936638
#
#      crude_birth_rate_(births_per_1,000_population)^2  \
# 0                                          107.412496
# 1                                          167.262489
# 2                                          108.388921
# 3                                          129.891609
# 4                                          114.704100
# ..                                                ...
# 465                                       1027.971844
# 466                                        601.475625
# 467                                       1374.555625
# 468                                        581.533225
# 469                                       1271.635600
#
#      crude_birth_rate_(births_per_1,000_population) deaths_-_unsafe_water_source_per_100k_people  \
# 0                                             0.312531
# 1                                             0.275477
# 2                                             0.744552
# 3                                             0.745077
# 4                                             0.728765
# ..                                                 ...
# 465                                        1301.851593
# 466                                           5.641028
# 467                                        1518.703598
# 468                                           5.466123
# 469                                        5360.000368
#
#      crude_birth_rate_(births_per_1,000_population) deaths_-_conflict_and_terrorism  \
# 0                                             0.000000
# 1                                             0.000000
# 2                                             0.367382
# 3                                             0.000000
# 4                                             0.000000
# ..                                                 ...
# 465                                           1.021557
# 466                                        7563.746323
# 467                                           2.953738
# 468                                        5503.436868
# 469                                        1449.543231
#
#      deaths_-_unsafe_water_source_per_100k_people^2  \
# 0                                          0.000909
# 1                                          0.000454
# 2                                          0.005115
# 3                                          0.004274
# 4                                          0.004630
# ..                                              ...
# 465                                     1648.700380
# 466                                        0.052905
# 467                                     1677.968193
# 468                                        0.051379
# 469                                    22592.638919
#
#      deaths_-_unsafe_water_source_per_100k_people deaths_-_conflict_and_terrorism  \
# 0                                             0.000000
# 1                                             0.000000
# 2                                             0.002524
# 3                                             0.000000
# 4                                             0.000000
# ..                                                 ...
# 465                                           1.293727
# 466                                          70.937712
# 467                                           3.263493
# 468                                          51.729565
# 469                                        6109.888913
#
#      deaths_-_conflict_and_terrorism^2
# 0                             0.000000
# 1                             0.000000
# 2                             0.001245
# 3                             0.000000
# 4                             0.000000
# ..                                 ...
# 465                           0.001015
# 466                       95116.503578
# 467                           0.006347
# 468                       52082.694602
# 469                        1652.340953
#
# [470 rows x 104 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, random_state = 42, stratify=Y)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train), lr.score(X_test, y_test), cross_val_score(lr, X_train, y_train).mean()
# Out:
# (0.6952908754968175, -11.984025553206264, -5.168356178143373)

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/ucdp-brd-dyadic-211.csv')

# %%
df.head(5)
# Out:
#    conflict_id  dyad_id      location_inc                          side_a  \
# 0        11447    10006          Ethiopia          Government of Ethiopia
# 1          372    10054              Mali              Government of Mali
# 2          283    10509  DR Congo (Zaire)  Government of DR Congo (Zaire)
# 3          283    10509  DR Congo (Zaire)  Government of DR Congo (Zaire)
# 4          283    10509  DR Congo (Zaire)  Government of DR Congo (Zaire)
#
#   side_a_id                                         side_a_2nd side_b  \
# 0        97                                                NaN   IGLF
# 1        72                                                NaN   FPLA
# 2        89  Government of Malawi, Government of South Afri...  APCLS
# 3        89  Government of Malawi, Government of South Afri...  APCLS
# 4        89  Government of Malawi, Government of South Afri...  APCLS
#
#   side_b_id side_b_2nd  incompatibility  ... type_of_conflict  \
# ...

# %%
df[df['year'] == 2019]
# Out:
#       conflict_id  dyad_id              location_inc  \
# 10          13646    10589                     Kenya
# 42            283    11377          DR Congo (Zaire)
# 45            223    11387           Myanmar (Burma)
# 66            299    11973                     Syria
# 111           374    12102                    Rwanda
# ...           ...      ...                       ...
# 1264          354      781                    Turkey
# 1297          364      792                     India
# 1546          404      857                  Pakistan
# 1624          418      878  United States of America
# 1662          423      888                  Thailand
#
#                                       side_a side_a_id  \
# 10                       Government of Kenya        91
# 42            Government of DR Congo (Zaire)        89
# 45             Government of Myanmar (Burma)       144
# 66                       Government of Syria       118
# ...
